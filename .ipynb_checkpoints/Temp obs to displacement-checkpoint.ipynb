# %%
# mle function import
from IPython.display import display, HTML
# display(HTML("<style>.container { width:80% !important; }</style>"))

import os
import shutil
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib as mpl
import datetime
import numpy as np 
import importlib
import cmocean as cm
import sys
import glob
import functions

# %%
plt.rcParams['axes.labelsize'] = 'medium'
plt.rcParams['font.size'] = 14
plt.rcParams['figure.figsize'] = [25, 10]
#np.set_printoptions(threshold=sys.maxsize)
plt.rcParams['animation.embed_limit'] = 2**128

# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Gourp the souce data files

# %%
from functions import Processing
# Out:
# d2spike not available
# pyODAS not found, not importing pIMOS.xrwrap.rsi_vmp
# No .afloatconfig config file found!

# %%
importlib.reload(Processing)
#downloaded nc files from imos
source_directory = 'TS_source_files'
#where to store the grouped nc files accoring to their trip number
destination_directory = 'Grouped_source_files'
#cluster the dowloaded nc files
Processing.Group_nc_files(source_directory, destination_directory,)
# Out:
# Move and group completed

# %% [markdown]
# ## Modulate attrs name

# %%
attrs_to_join = [
    'project',
    'trip',
    'trip_deployed',
    'site',
    'site_station',
    'instrument_make',
    'instrument_model',
    'instrument_serial_number',
    'raw_file_name',
    'raw_file_directory',
    'raw_file_attributes',
    'disclaimer',
    'nominal_latitude',
    'nominal_longitude',
    'nominal_site_depth',
    'nominal_instrument_height_asb',
    'timezone',
]

# %%
selected_raw_attrs = [
    'author',
    'title',
    'deployment_code',
    'site_code',
    'site_code',
    'instrument',
    'instrument',
    'instrument_serial_number',
    'title',
    'title',
    'title',
    'disclaimer',
    'geospatial_lat_max',
    'geospatial_lon_max',
    'site_depth_at_deployment',
    'instrument_nominal_depth',
    'time_deployment_start',
]

# %% [markdown]
# ## Converting IMOS data

# %%
from functions import Processing
importlib.reload(Processing)
# Out:
# <module 'functions.Processing' from 'C:\\Users\\21924032\\GitHub\\Normal-Mode-Decomposition-of-the-Internal-Wave\\functions\\Processing.py'>

# %%
#group_source_file_di/destination_directory is where gourped source file stored
group_source_file_dir = destination_directory
Processing.Process_Gourp_IMOS_source_file(group_source_file_dir,['TEMP', 'z_hat'],attrs_to_join, selected_raw_attrs,
                                          window_duration = 85)
# Out:
# Failed to process C:\Users\21924032\GitHub\Normal-Mode-Decomposition-of-the-Internal-Wave\Grouped_source_files\ITFTIS-1006\IMOS_ANMN-QLD_TZ_20100630T033000Z_ITFTIS_FV01_ITFTIS-1006-SensusUltra-13_END-20110107T003000Z_C-20131112T002040Z.nc: "No variable named 'NOMINAL_DEPTH'. Variables on the dataset include ['TIME', 'TIME_quality_control', 'LATITUDE', 'LATITUDE_quality_control', 'LONGITUDE', ..., 'TEMP_quality_control', 'PRES', 'PRES_quality_control', 'DEPTH', 'DEPTH_quality_control']"
# data of ITFTIS-1707 at depth of -37.0 m has duration of 32.0 days so short that excluding
# Failed to process C:\Users\21924032\GitHub\Normal-Mode-Decomposition-of-the-Internal-Wave\Grouped_source_files\KIM400-1301\IMOS_ANMN-QLD_TZ_20130125T000000Z_KIM400_FV01_KIM400-1301-SBE39-41_END-20130126T080000Z_C-20160303T015152Z.nc: index -1 is out of bounds for axis 0 with size 0
# data of NWSBRW-2009 at depth of -29.0 m has duration of 74.0 days so short that excluding
# data of NWSBRW-2111 at depth of -166.89999389648438 m has duration of 2.0 days so short that excluding
# data of NWSBRW-2210 at depth of -41.5 m has duration of 2.0 days so short that excluding
# data of NWSBRW-2305 at depth of -197.5 m has duration of 16.0 days so short that excluding
# data of NWSLYN-2210 at depth of -157.0 m has duration of 53.0 days so short that excluding
# data of NWSLYN-2305 at depth of -55.0 m has duration of 82.0 days so short that excluding
# data of NWSROW-1907 at depth of -77.19999694824219 m has duration of 60.0 days so short that excluding
# IMOS Lv1 data processing completed, name as PL1 Data

# %% [markdown]
# # Stack data using pIMOS --- (PL2)

# %%
importlib.reload(Processing)
dt_sec = 60*5 #second
z_method = 'z_nom'
#def stack_variabiles
stack_variables = ['TEMP','z_hat']
Processing.Construct_PL2_data('PL1 Data','PL2 Stacked data', stack_variables,dt_sec = dt_sec)
# Out:
# Loading file 0 of 9
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.81705 127.5533166667
#     File starts 2010-06-30T03:30:00.000013312
# Blanking 0 values.
# Blanking 27400 values.
# Loading file 1 of 9
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.81705 127.5533166667
#     File starts 2010-06-30T03:30:00.000013312
# Blanking 232 values.
# Blanking 22777 values.
# Loading file 2 of 9
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.81705 127.5533166667
#     File starts 2010-06-30T03:30:00.000013312
# Blanking 0 values.
# Blanking 27400 values.
# Loading file 3 of 9
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.81705 127.5533166667
#     File starts 2010-06-30T03:30:24.000003840
# Blanking 0 values.
# Blanking 0 values.
# Loading file 4 of 9
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.81705 127.5533166667
#     File starts 2010-06-30T03:30:00.000013312
# Blanking 0 values.
# Blanking 27400 values.
# Loading file 5 of 9
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.81705 127.5533166667
#     File starts 2010-06-30T03:30:00.000013312
# Blanking 0 values.
# Blanking 27388 values.
# Loading file 6 of 9
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.81705 127.5533166667
#     File starts 2010-06-30T03:30:00.000013312
# Blanking 0 values.
# Blanking 0 values.
# Loading file 7 of 9
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.81705 127.5533166667
#     File starts 2010-06-30T03:30:00.999997952
# Blanking 0 values.
# Blanking 306 values.
# Loading file 8 of 9
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.81705 127.5533166667
#     File starts 2010-06-30T03:30:00.999997952
# Blanking 0 values.
# Blanking 5392 values.
# <xarray.DataArray 'lon_nom' ()> Size: 8B
# array(127.553317)
# Coordinates:
#     lat_nom  float64 8B -9.817
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -128.3
# Attributes:
#     axis:             X
#     long_name:        longitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    longitude
#     units:            degrees_east
#     valid_max:        180.0
#     valid_min:        -180.0
# <xarray.DataArray 'lat_nom' ()> Size: 8B
# array(-9.81705)
# Coordinates:
#     lat_nom  float64 8B -9.817
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -128.3
# Attributes:
#     axis:             Y
#     long_name:        latitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    latitude
#     units:            degrees_north
#     valid_max:        90.0
#     valid_min:        -90.0
# Initialising accessor.
# Mooring made by stacking multipe files
# Mooring made by stacking multipe files
# pIMOS
# pIMOS
# 2
# 2
# Loading file 0 of 11
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8168333333 127.5531333333
#     File starts 2011-01-08T01:30:01.000004608
# Blanking 0 values.
# Blanking 0 values.
# Loading file 1 of 11
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8168333333 127.5531333333
#     File starts 2011-01-08T01:30:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 2 of 11
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8168333333 127.5531333333
#     File starts 2011-01-08T01:30:00.000000000
# Blanking 1 values.
# Blanking 0 values.
# Loading file 3 of 11
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8168333333 127.5531333333
#     File starts 2011-01-08T01:30:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 4 of 11
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8168333333 127.5531333333
#     File starts 2011-01-08T01:30:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 5 of 11
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8168333333 127.5531333333
#     File starts 2011-01-08T01:30:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 6 of 11
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8168333333 127.5531333333
#     File starts 2011-01-08T01:30:01.000004608
# Blanking 2 values.
# Blanking 0 values.
# Loading file 7 of 11
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8168333333 127.5531333333
#     File starts 2011-01-08T01:30:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 8 of 11
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8168333333 127.5531333333
#     File starts 2011-01-08T01:30:01.000004608
# Blanking 1 values.
# Blanking 0 values.
# Loading file 9 of 11
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8168333333 127.5531333333
#     File starts 2011-01-08T01:30:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 10 of 11
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8168333333 127.5531333333
#     File starts 2011-01-08T13:54:43.000002816
# Blanking 0 values.
# Blanking 0 values.
# <xarray.DataArray 'lon_nom' ()> Size: 8B
# array(127.553133)
# Coordinates:
#     lat_nom  float64 8B -9.817
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -100.0
# Attributes:
#     axis:             X
#     long_name:        longitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    longitude
#     units:            degrees_east
#     valid_max:        180.0
#     valid_min:        -180.0
# <xarray.DataArray 'lat_nom' ()> Size: 8B
# array(-9.816833)
# Coordinates:
#     lat_nom  float64 8B -9.817
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -100.0
# Attributes:
#     axis:             Y
#     long_name:        latitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    latitude
#     units:            degrees_north
#     valid_max:        90.0
#     valid_min:        -90.0
# Initialising accessor.
# Mooring made by stacking multipe files
# Mooring made by stacking multipe files
# pIMOS
# pIMOS
# 2
# 2
# Loading file 0 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T04:30:00.000000000
# Blanking 14 values.
# Blanking 46040 values.
# Loading file 1 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T04:31:38.999996160
# Blanking 6 values.
# Blanking 22272 values.
# Loading file 2 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T12:00:24.999985152
# Blanking 15 values.
# Blanking 99 values.
# Loading file 3 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T04:30:00.000000000
# Blanking 6 values.
# Blanking 46042 values.
# Loading file 4 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T04:30:00.000000000
# Blanking 7 values.
# Blanking 46042 values.
# Loading file 5 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T04:03:19.999998208
# Blanking 7 values.
# Blanking 46060 values.
# Loading file 6 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T04:30:00.000000000
# Blanking 71 values.
# Blanking 184810 values.
# Loading file 7 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T12:00:24.999985152
# Blanking 0 values.
# Blanking 77 values.
# Loading file 8 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T04:30:00.000000000
# Blanking 72 values.
# Blanking 184810 values.
# Loading file 9 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T04:30:01.000004608
# Blanking 7 values.
# Blanking 1008 values.
# Loading file 10 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T04:30:00.000000000
# Blanking 170 values.
# Blanking 183545 values.
# Loading file 11 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T04:30:00.000000000
# Blanking 1 values.
# Blanking 16662 values.
# Loading file 12 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T04:30:00.000000000
# Blanking 77 values.
# Blanking 146 values.
# Loading file 13 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T04:30:01.000004608
# Blanking 0 values.
# Blanking 1962 values.
# Loading file 14 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T04:31:27.999995392
# Blanking 1 values.
# Blanking 23993 values.
# Loading file 15 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T04:30:01.000004608
# Blanking 0 values.
# Blanking 15699 values.
# Loading file 16 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8175833333 127.5539666667
#     File starts 2011-05-30T04:30:01.000004608
# Blanking 8 values.
# Blanking 42176 values.
# <xarray.DataArray 'lon_nom' ()> Size: 8B
# array(127.553967)
# Coordinates:
#     lat_nom  float64 8B -9.818
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -110.7
# Attributes:
#     axis:             X
#     long_name:        longitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    longitude
#     units:            degrees_east
#     valid_max:        180.0
#     valid_min:        -180.0
# <xarray.DataArray 'lat_nom' ()> Size: 8B
# array(-9.817583)
# Coordinates:
#     lat_nom  float64 8B -9.818
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -110.7
# Attributes:
#     axis:             Y
#     long_name:        latitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    latitude
#     units:            degrees_north
#     valid_max:        90.0
#     valid_min:        -90.0
# Initialising accessor.
# Mooring made by stacking multipe files
# Mooring made by stacking multipe files
# pIMOS
# pIMOS
# 2
# 2
# Loading file 0 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:49.000002560
# Blanking 0 values.
# Blanking 2 values.
# Loading file 1 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:49.000002560
# Blanking 0 values.
# Blanking 2 values.
# Loading file 2 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:49.000002560
# Blanking 0 values.
# Blanking 2 values.
# Loading file 3 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:29:59.999996672
# Blanking 0 values.
# Blanking 0 values.
# Loading file 4 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:49.000002560
# Blanking 0 values.
# Blanking 2 values.
# Loading file 5 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:49.000002560
# Blanking 0 values.
# Blanking 2 values.
# Loading file 6 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:49.000002560
# Blanking 0 values.
# Blanking 2 values.
# Loading file 7 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:49.000002560
# Blanking 0 values.
# Blanking 0 values.
# Loading file 8 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:49.000002560
# Blanking 0 values.
# Blanking 2 values.
# Loading file 9 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:49.000002560
# Blanking 0 values.
# Blanking 1 values.
# Loading file 10 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:01.000001280
# Blanking 0 values.
# Blanking 0 values.
# Loading file 11 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:49.000002560
# Blanking 0 values.
# Blanking 2 values.
# Loading file 12 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:49.000002560
# Blanking 0 values.
# Blanking 1 values.
# Loading file 13 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:49.000002560
# Blanking 0 values.
# Blanking 0 values.
# Loading file 14 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:32:12.999999488
# Blanking 0 values.
# Blanking 0 values.
# Loading file 15 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:01.000001280
# Blanking 0 values.
# Blanking 0 values.
# Loading file 16 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:43.999999488
# Blanking 0 values.
# Blanking 0 values.
# Loading file 17 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:01.000001280
# Blanking 6 values.
# Blanking 0 values.
# Loading file 18 of 19
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8173833333 127.5541333333
#     File starts 2012-01-11T02:30:01.000001280
# Blanking 0 values.
# Blanking 0 values.
# <xarray.DataArray 'lon_nom' ()> Size: 8B
# array(127.554133)
# Coordinates:
#     lat_nom  float64 8B -9.817
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -112.0
# Attributes:
#     axis:             X
#     long_name:        longitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    longitude
#     units:            degrees_east
#     valid_max:        180.0
#     valid_min:        -180.0
# <xarray.DataArray 'lat_nom' ()> Size: 8B
# array(-9.817383)
# Coordinates:
#     lat_nom  float64 8B -9.817
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -112.0
# Attributes:
#     axis:             Y
#     long_name:        latitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    latitude
#     units:            degrees_north
#     valid_max:        90.0
#     valid_min:        -90.0
# Initialising accessor.
# Mooring made by stacking multipe files
# Mooring made by stacking multipe files
# pIMOS
# pIMOS
# 2
# 2
# Loading file 0 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:48.959997184
# Blanking 0 values.
# Blanking 0 values.
# Loading file 1 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:39.974399232
# Blanking 0 values.
# Blanking 0 values.
# Loading file 2 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:00.000003328
# Blanking 0 values.
# Blanking 0 values.
# Loading file 3 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:48.959997184
# Blanking 0 values.
# Blanking 0 values.
# Loading file 4 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:48.959997184
# Blanking 0 values.
# Blanking 0 values.
# Loading file 5 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:04.982404352
# Blanking 0 values.
# Blanking 0 values.
# Loading file 6 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:48.959997184
# Blanking 0 values.
# Blanking 0 values.
# Loading file 7 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:48.959997184
# Blanking 0 values.
# Blanking 0 values.
# Loading file 8 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:48.959997184
# Blanking 0 values.
# Blanking 0 values.
# Loading file 9 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:44.985597184
# Blanking 0 values.
# Blanking 0 values.
# Loading file 10 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:00.999997952
# Blanking 0 values.
# Blanking 0 values.
# Loading file 11 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:27.014401280
# Blanking 0 values.
# Blanking 0 values.
# Loading file 12 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:04.982404352
# Blanking 0 values.
# Blanking 0 values.
# Loading file 13 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:48.959997184
# Blanking 0 values.
# Blanking 0 values.
# Loading file 14 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:00.999997952
# Blanking 0 values.
# Blanking 0 values.
# Loading file 15 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:48.959997184
# Blanking 0 values.
# Blanking 0 values.
# Loading file 16 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:00.999997952
# Blanking 0 values.
# Blanking 0 values.
# Loading file 17 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194333333 127.54705
#     File starts 2012-07-22T05:00:01.008004352
# Blanking 0 values.
# Blanking 0 values.
# <xarray.DataArray 'lon_nom' ()> Size: 8B
# array(127.54705)
# Coordinates:
#     lat_nom  float64 8B -9.819
#     lon_nom  float64 8B 127.5
#     z_nom    float32 4B -110.5
# Attributes:
#     axis:             X
#     long_name:        longitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    longitude
#     units:            degrees_east
#     valid_max:        180.0
#     valid_min:        -180.0
# <xarray.DataArray 'lat_nom' ()> Size: 8B
# array(-9.819433)
# Coordinates:
#     lat_nom  float64 8B -9.819
#     lon_nom  float64 8B 127.5
#     z_nom    float32 4B -110.5
# Attributes:
#     axis:             Y
#     long_name:        latitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    latitude
#     units:            degrees_north
#     valid_max:        90.0
#     valid_min:        -90.0
# Initialising accessor.
# Mooring made by stacking multipe files
# Mooring made by stacking multipe files
# pIMOS
# pIMOS
# 2
# 2
# Loading file 0 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T10:00:29.000000256
# Blanking 0 values.
# Blanking 0 values.
# Loading file 1 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T10:00:29.000000256
# Blanking 0 values.
# Blanking 0 values.
# Loading file 2 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T09:59:59.999996672
# Blanking 0 values.
# Blanking 0 values.
# Loading file 3 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T10:00:12.999996416
# Blanking 0 values.
# Blanking 0 values.
# Loading file 4 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T10:00:29.000000256
# Blanking 0 values.
# Blanking 0 values.
# Loading file 5 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T10:00:29.000000256
# Blanking 0 values.
# Blanking 0 values.
# Loading file 6 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T09:59:59.999996672
# Blanking 0 values.
# Blanking 0 values.
# Loading file 7 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T10:00:29.000000256
# Blanking 0 values.
# Blanking 0 values.
# Loading file 8 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T10:00:29.000000256
# Blanking 0 values.
# Blanking 0 values.
# Loading file 9 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T10:00:01.000001280
# Blanking 0 values.
# Blanking 0 values.
# Loading file 10 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T10:00:28.972802560
# Blanking 0 values.
# Blanking 0 values.
# Loading file 11 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T10:00:29.000000256
# Blanking 0 values.
# Blanking 0 values.
# Loading file 12 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T09:59:59.999996672
# Blanking 0 values.
# Blanking 0 values.
# Loading file 13 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T10:00:14.000001280
# Blanking 0 values.
# Blanking 0 values.
# Loading file 14 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T10:00:01.000001280
# Blanking 38 values.
# Blanking 0 values.
# Loading file 15 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T10:00:29.000000256
# Blanking 0 values.
# Blanking 0 values.
# Loading file 16 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T10:00:01.000001280
# Blanking 0 values.
# Blanking 0 values.
# Loading file 17 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8194833333 127.5517833333
#     File starts 2012-12-13T10:00:01.000001280
# Blanking 0 values.
# Blanking 0 values.
# <xarray.DataArray 'lon_nom' ()> Size: 8B
# array(127.551783)
# Coordinates:
#     lat_nom  float64 8B -9.819
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -109.5
# Attributes:
#     axis:             X
#     long_name:        longitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    longitude
#     units:            degrees_east
#     valid_max:        180.0
#     valid_min:        -180.0
# <xarray.DataArray 'lat_nom' ()> Size: 8B
# array(-9.819483)
# Coordinates:
#     lat_nom  float64 8B -9.819
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -109.5
# Attributes:
#     axis:             Y
#     long_name:        latitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    latitude
#     units:            degrees_north
#     valid_max:        90.0
#     valid_min:        -90.0
# Initialising accessor.
# Mooring made by stacking multipe files
# Mooring made by stacking multipe files
# pIMOS
# pIMOS
# 2
# 2
# Loading file 0 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 1 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 2 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 3 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 4 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:00.000003328
# Blanking 0 values.
# Blanking 35 values.
# Loading file 5 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 6 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 7 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 8 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 9 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 10 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:00.999997952
# Blanking 0 values.
# Blanking 0 values.
# Loading file 11 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 12 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 13 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 14 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:00.999997952
# Blanking 0 values.
# Blanking 0 values.
# Loading file 15 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 16 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:00.999997952
# Blanking 0 values.
# Blanking 0 values.
# Loading file 17 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8176666667 127.5539
#     File starts 2013-06-20T09:30:00.999997952
# Blanking 0 values.
# Blanking 0 values.
# <xarray.DataArray 'lon_nom' ()> Size: 8B
# array(127.5539)
# Coordinates:
#     lat_nom  float64 8B -9.818
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -114.0
# Attributes:
#     standard_name:    longitude
#     long_name:        longitude
#     units:            degrees_east
#     axis:             X
#     reference_datum:  WGS84 coordinate reference system
#     valid_min:        -180.0
#     valid_max:        180.0
# <xarray.DataArray 'lat_nom' ()> Size: 8B
# array(-9.817667)
# Coordinates:
#     lat_nom  float64 8B -9.818
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -114.0
# Attributes:
#     standard_name:    latitude
#     long_name:        latitude
#     units:            degrees_north
#     axis:             Y
#     reference_datum:  WGS84 coordinate reference system
#     valid_min:        -90.0
#     valid_max:        90.0
# Initialising accessor.
# Mooring made by stacking multipe files
# Mooring made by stacking multipe files
# pIMOS
# pIMOS
# 2
# 2
# Loading file 0 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:29.000000256
# Blanking 0 values.
# Blanking 0 values.
# Loading file 1 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:29.000000256
# Blanking 0 values.
# Blanking 2 values.
# Loading file 2 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:29.000000256
# Blanking 0 values.
# Blanking 2 values.
# Loading file 3 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:19:59.999998976
# Blanking 0 values.
# Blanking 0 values.
# Loading file 4 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:29.000000256
# Blanking 0 values.
# Blanking 2 values.
# Loading file 5 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:29.000000256
# Blanking 0 values.
# Blanking 2 values.
# Loading file 6 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:29.000000256
# Blanking 0 values.
# Blanking 2 values.
# Loading file 7 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:29.000000256
# Blanking 0 values.
# Blanking 0 values.
# Loading file 8 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:29.000000256
# Blanking 0 values.
# Blanking 0 values.
# Loading file 9 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:29.000000256
# Blanking 0 values.
# Blanking 2 values.
# Loading file 10 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:01.000001280
# Blanking 0 values.
# Blanking 0 values.
# Loading file 11 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:29.000000256
# Blanking 0 values.
# Blanking 2 values.
# Loading file 12 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:29.000000256
# Blanking 0 values.
# Blanking 2 values.
# Loading file 13 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:29.000000256
# Blanking 0 values.
# Blanking 0 values.
# Loading file 14 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:01.000001280
# Blanking 0 values.
# Blanking 0 values.
# Loading file 15 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:29.000000256
# Blanking 0 values.
# Blanking 0 values.
# Loading file 16 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:01.000001280
# Blanking 0 values.
# Blanking 0 values.
# Loading file 17 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8174666667 127.55425
#     File starts 2014-01-10T06:15:01.000001280
# Blanking 0 values.
# Blanking 0 values.
# <xarray.DataArray 'lon_nom' ()> Size: 8B
# array(127.55425)
# Coordinates:
#     lat_nom  float64 8B -9.817
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -112.0
# Attributes:
#     axis:             X
#     long_name:        longitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    longitude
#     units:            degrees_east
#     valid_max:        180.0
#     valid_min:        -180.0
# <xarray.DataArray 'lat_nom' ()> Size: 8B
# array(-9.817467)
# Coordinates:
#     lat_nom  float64 8B -9.817
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -112.0
# Attributes:
#     axis:             Y
#     long_name:        latitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    latitude
#     units:            degrees_north
#     valid_max:        90.0
#     valid_min:        -90.0
# Initialising accessor.
# Mooring made by stacking multipe files
# Mooring made by stacking multipe files
# pIMOS
# pIMOS
# 2
# 2
# Loading file 0 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 1 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 2 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:01.000007936
# Blanking 13 values.
# Blanking 0 values.
# Loading file 3 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:01.000007936
# Blanking 0 values.
# Blanking 0 values.
# Loading file 4 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 5 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 6 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 7 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:01.000007936
# Blanking 0 values.
# Blanking 0 values.
# Loading file 8 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 9 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:01.000007936
# Blanking 0 values.
# Blanking 0 values.
# Loading file 10 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:00.000003328
# Blanking 0 values.
# Blanking 0 values.
# Loading file 11 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:28.999996928
# Blanking 0 values.
# Blanking 2 values.
# Loading file 12 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 13 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:28.999996928
# Blanking 0 values.
# Blanking 2 values.
# Loading file 14 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 15 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:01.000007936
# Blanking 0 values.
# Blanking 0 values.
# Loading file 16 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:28.999996928
# Blanking 0 values.
# Blanking 0 values.
# Loading file 17 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -9.8148166667 127.5610833333
#     File starts 2014-09-08T23:00:00.000003328
# Blanking 0 values.
# Blanking 0 values.
# <xarray.DataArray 'lon_nom' ()> Size: 8B
# array(127.561083)
# Coordinates:
#     lat_nom  float64 8B -9.815
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -109.0
# Attributes:
#     axis:             X
#     long_name:        longitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    longitude
#     units:            degrees_east
#     valid_max:        180.0
#     valid_min:        -180.0
# <xarray.DataArray 'lat_nom' ()> Size: 8B
# array(-9.814817)
# Coordinates:
#     lat_nom  float64 8B -9.815
#     lon_nom  float64 8B 127.6
#     z_nom    float32 4B -109.0
# Attributes:
#     axis:             Y
#     long_name:        latitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    latitude
#     units:            degrees_north
#     valid_max:        90.0
#     valid_min:        -90.0
# Initialising accessor.
# Mooring made by stacking multipe files
# Mooring made by stacking multipe files
# pIMOS
# pIMOS
# 2
# 2
# Loading file 0 of 18
# pl0 init
# ...
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:01.000004608
# Blanking 0 values.
# Blanking 0 values.
# Loading file 1 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 2 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:01.000004608
# Blanking 0 values.
# Blanking 0 values.
# Loading file 3 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 4 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 5 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:01.000004608
# Blanking 0 values.
# Blanking 0 values.
# Loading file 6 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 7 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:01.000004608
# Blanking 0 values.
# Blanking 0 values.
# Loading file 8 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:03.999998464
# Blanking 0 values.
# Blanking 0 values.
# Loading file 9 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:01.000004608
# Blanking 0 values.
# Blanking 0 values.
# Loading file 10 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:01.000004608
# Blanking 0 values.
# Blanking 0 values.
# Loading file 11 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 12 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:01.000004608
# Blanking 0 values.
# Blanking 0 values.
# Loading file 13 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 14 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:01.000004608
# Blanking 0 values.
# Blanking 0 values.
# Loading file 15 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 16 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:01.000004608
# Blanking 0 values.
# Blanking 0 values.
# Loading file 17 of 18
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4355833333 115.9155
#     File starts 2013-02-05T04:30:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# <xarray.DataArray 'lon_nom' ()> Size: 8B
# array(115.9155)
# Coordinates:
#     lat_nom  float64 8B -19.44
#     lon_nom  float64 8B 115.9
#     z_nom    float32 4B -106.0
# Attributes:
#     axis:             X
#     long_name:        longitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    longitude
#     units:            degrees_east
#     valid_max:        180.0
#     valid_min:        -180.0
# <xarray.DataArray 'lat_nom' ()> Size: 8B
# array(-19.435583)
# Coordinates:
#     lat_nom  float64 8B -19.44
#     lon_nom  float64 8B 115.9
#     z_nom    float32 4B -106.0
# Attributes:
#     axis:             Y
#     long_name:        latitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    latitude
#     units:            degrees_north
#     valid_max:        90.0
#     valid_min:        -90.0
# Initialising accessor.
# Mooring made by stacking multipe files
# Mooring made by stacking multipe files
# pIMOS
# pIMOS
# 2
# 2
# Loading file 0 of 14
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4354666667 115.9150833333
#     File starts 2013-08-03T07:45:01.000001280
# Blanking 0 values.
# Blanking 0 values.
# Loading file 1 of 14
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4354666667 115.9150833333
#     File starts 2013-08-03T07:46:00.000003072
# Blanking 0 values.
# Blanking 0 values.
# Loading file 2 of 14
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4354666667 115.9150833333
#     File starts 2013-08-03T07:46:00.000003072
# Blanking 0 values.
# Blanking 0 values.
# Loading file 3 of 14
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4354666667 115.9150833333
#     File starts 2013-08-03T07:45:01.000001280
# Blanking 0 values.
# Blanking 0 values.
# Loading file 4 of 14
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4354666667 115.9150833333
#     File starts 2013-08-03T07:46:00.000003072
# Blanking 0 values.
# Blanking 0 values.
# Loading file 5 of 14
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4354666667 115.9150833333
#     File starts 2013-08-03T07:45:01.000001280
# Blanking 3 values.
# Blanking 0 values.
# Loading file 6 of 14
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4354666667 115.9150833333
#     File starts 2013-08-03T07:45:01.000001280
# Blanking 0 values.
# Blanking 0 values.
# Loading file 7 of 14
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4354666667 115.9150833333
#     File starts 2013-08-03T07:45:00.028803584
# Blanking 0 values.
# Blanking 0 values.
# Loading file 8 of 14
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4354666667 115.9150833333
#     File starts 2013-08-03T07:46:00.000003072
# Blanking 0 values.
# Blanking 0 values.
# Loading file 9 of 14
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4354666667 115.9150833333
#     File starts 2013-08-03T07:45:59.990397440
# Blanking 0 values.
# Blanking 0 values.
# Loading file 10 of 14
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4354666667 115.9150833333
#     File starts 2013-08-03T07:46:00.000003072
# Blanking 0 values.
# Blanking 0 values.
# Loading file 11 of 14
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4354666667 115.9150833333
#     File starts 2013-08-03T07:46:00.000003072
# Blanking 0 values.
# Blanking 0 values.
# Loading file 12 of 14
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4354666667 115.9150833333
#     File starts 2013-08-03T07:45:00.028803584
# Blanking 0 values.
# Blanking 0 values.
# Loading file 13 of 14
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4354666667 115.9150833333
#     File starts 2013-08-03T07:46:00.000003072
# Blanking 0 values.
# Blanking 0 values.
# <xarray.DataArray 'lon_nom' ()> Size: 8B
# array(115.915083)
# Coordinates:
#     lat_nom  float64 8B -19.44
#     lon_nom  float64 8B 115.9
#     z_nom    float32 4B -106.0
# Attributes:
#     axis:             X
#     long_name:        longitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    longitude
#     units:            degrees_east
#     valid_max:        180.0
#     valid_min:        -180.0
# <xarray.DataArray 'lat_nom' ()> Size: 8B
# array(-19.435467)
# Coordinates:
#     lat_nom  float64 8B -19.44
#     lon_nom  float64 8B 115.9
#     z_nom    float32 4B -106.0
# Attributes:
#     axis:             Y
#     long_name:        latitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    latitude
#     units:            degrees_north
#     valid_max:        90.0
#     valid_min:        -90.0
# Initialising accessor.
# Mooring made by stacking multipe files
# Mooring made by stacking multipe files
# pIMOS
# pIMOS
# 2
# 2
# Loading file 0 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:01.000004608
# Blanking 0 values.
# Blanking 0 values.
# Loading file 1 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 2 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:00.000000000
# Blanking 0 values.
# Blanking 579 values.
# Loading file 3 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 4 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:01.000004608
# Blanking 0 values.
# Blanking 0 values.
# Loading file 5 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 6 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:00.999994624
# Blanking 0 values.
# Blanking 0 values.
# Loading file 7 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 8 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T20:02:01.000000768
# Blanking 0 values.
# Blanking 0 values.
# Loading file 9 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:00.999994624
# Blanking 0 values.
# Blanking 0 values.
# Loading file 10 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 11 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 12 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:01.000004608
# Blanking 0 values.
# Blanking 0 values.
# Loading file 13 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 14 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# Loading file 15 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:00.999994624
# Blanking 0 values.
# Blanking 0 values.
# Loading file 16 of 17
# pl0 init
# Initialising Process Level 0
# Wrapped an existing xarray dataset. Class attributes taken from the dataset. Dataset attrs cleared.
# -19.4353333333 115.9154
#     File starts 2014-02-11T09:00:00.000000000
# Blanking 0 values.
# Blanking 0 values.
# <xarray.DataArray 'lon_nom' ()> Size: 8B
# array(115.9154)
# Coordinates:
#     lat_nom  float64 8B -19.44
#     lon_nom  float64 8B 115.9
#     z_nom    float32 4B -109.0
# Attributes:
#     axis:             X
#     long_name:        longitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    longitude
#     units:            degrees_east
#     valid_max:        180.0
#     valid_min:        -180.0
# <xarray.DataArray 'lat_nom' ()> Size: 8B
# array(-19.435333)
# Coordinates:
#     lat_nom  float64 8B -19.44
#     lon_nom  float64 8B 115.9
#     z_nom    float32 4B -109.0
# Attributes:
#     axis:             Y
#     long_name:        latitude
#     reference_datum:  WGS84 geographic coordinate system
#     standard_name:    latitude
#     units:            degrees_north
#     valid_max:        90.0
#     valid_min:        -90.0
# Initialising accessor.
# Mooring made by stacking multipe files
# Mooring made by stacking multipe files
# pIMOS
# pIMOS
# 2
# 2
# The number of folders in 1 (67) and 2 (67) are equal.
# IMOS Lv2 data processing completed, named asPL2 Stacked data

# %% [markdown]
# # Displacement estimation --- (PL3)

# %%
importlib.reload(Processing)
stack_variables = ['TEMP']
Processing.Construct_PL3_data('PL2 Stacked data','PL3 Stacked data_mode_3 - density fit - single_tanh', stack_variables,nmodes=3, z_method = 'z_nom',
                              fit=True,density_func='single_tanh')
# Out:
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "title" to "Level 3 process file made from level 2 stacked mooring"
# Setting attribute "institution" to "The University of Western Australia"
# Setting attribute "institution_division" to "Ocean Dynamics"
# Setting attribute "source" to "pIMOS"
# Setting attribute "project" to "AIMS"
# Setting attribute "history" to ""
# Setting attribute "references" to ""
# Setting attribute "comment" to ""
# Setting attribute "Conventions" to "CF-1.7"
# Setting attribute "trip" to "7/01/2011"
# Setting attribute "trip_deployed" to "ITFTIS-1006;ITFTIS-1006;ITFTIS-1006;ITFTIS-1006;ITFTIS-1006;ITFTIS-1006;ITFTIS-1006;ITFTIS-1006;ITFTIS-1006"
# Setting attribute "site" to "ITFTIS"
# Setting attribute "site_station" to "ITFTIS"
# Setting attribute "instrument_make" to "BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE PRESSURE - TDR-2050;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE LOGGER TR-1060P;SEABIRD SBE37SM + P;SEABIRD SBE37SM + P"
# Setting attribute "instrument_model" to "BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE PRESSURE - TDR-2050;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE LOGGER TR-1060P;SEABIRD SBE37SM + P;SEABIRD SBE37SM + P"
# Setting attribute "instrument_serial_number" to "20176;20173;20167;16254;20168;20188;20129;4480;4479"
# Setting attribute "raw_file_name" to "7/01/2011;7/01/2011;7/01/2011;7/01/2011;7/01/2011;7/01/2011;7/01/2011;7/01/2011;7/01/2011"
# Setting attribute "raw_file_directory" to "7/01/2011;7/01/2011;7/01/2011;7/01/2011;7/01/2011;7/01/2011;7/01/2011;7/01/2011;7/01/2011"
# Setting attribute "raw_file_attributes" to "7/01/2011;7/01/2011;7/01/2011;7/01/2011;7/01/2011;7/01/2011;7/01/2011;7/01/2011;7/01/2011"
# Setting attribute "last_export_file_name" to ""
# Setting attribute "last_export_directory" to ""
# Setting attribute "last_load_file_name" to ""
# Setting attribute "last_load_directory" to ""
# Setting attribute "outfile_append" to ""
# Setting attribute "disclaimer" to "Data, products and services from IMOS are provided "as is" without any warranty as to fitness for a particular purpose."
# Setting attribute "nominal_latitude" to "-9.81705"
# Setting attribute "nominal_longitude" to "127.5533166667"
# Setting attribute "nominal_site_depth" to "465.8"
# Setting attribute "pressure_sensor_height_asb" to ""
# Setting attribute "nominal_instrument_height_asb" to "128.3;178.3;198.3;21.8;298.3;398.3;461.8;78.3;98.3"
# Setting attribute "nominal_instrument_orientation" to ""
# Setting attribute "timezone" to "2010-06-30"
# Setting attribute "process_level" to "3"
# Setting attribute "is_profile_data" to "0"
# Level 3 process file made from level 2 stacked mooring
# Level 3 process file made from level 2 stacked mooring
# pIMOS
# pIMOS
# 3
# 3
# Filling nans in Temperature
# Done.
# Calculating Salinity
# Done
# Calculating Density
# Pressure estimated from nominal depth.
# Done
# Creating slow time
# Done
# Calculating buoyancy modes
# C:\Users\21924032\GitHub\Normal-Mode-Decomposition-of-the-Internal-Wave\pIMOS_Tao\pIMOS\xrwrap\pl3_stacked_mooring.py:191: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   self.ds['timeslow'] = timeslow
# C:\Users\21924032\GitHub\Normal-Mode-Decomposition-of-the-Internal-Wave\pIMOS_Tao\pIMOS\xrwrap\pl3_stacked_mooring.py:191: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   self.ds['timeslow'] = timeslow
# Warning in density fit -- large error: 1.148775
# Warning in density fit -- large error: 1.148775
# Warning in density fit -- large error: 1.148775
# Warning in density fit -- large error: 1.184433
# Warning in density fit -- large error: 1.184433
# Warning in density fit -- large error: 1.184433
# Warning in density fit -- large error: 1.216030
# Warning in density fit -- large error: 1.216030
# Warning in density fit -- large error: 1.216030
# Warning in density fit -- large error: 2.970636
# Warning in density fit -- large error: 2.970636
# Warning in density fit -- large error: 2.970636
# Warning in density fit -- large error: 1.209972
# Warning in density fit -- large error: 1.209972
# Warning in density fit -- large error: 1.209972
# Warning in density fit -- large error: 2.994666
# Warning in density fit -- large error: 2.994666
# Warning in density fit -- large error: 2.994666
# Warning in density fit -- large error: 1.850243
# Warning in density fit -- large error: 1.850243
# Warning in density fit -- large error: 1.850243
# Warning in density fit -- large error: 2.975687
# Warning in density fit -- large error: 2.975687
# Warning in density fit -- large error: 2.975687
# Warning in density fit -- large error: 1.252424
# Warning in density fit -- large error: 1.252424
# Warning in density fit -- large error: 1.252424
# Warning in density fit -- large error: 1.265337
# Warning in density fit -- large error: 1.265337
# Warning in density fit -- large error: 1.265337
# Warning in density fit -- large error: 1.274104
# Warning in density fit -- large error: 1.274104
# Warning in density fit -- large error: 1.274104
# Warning in density fit -- large error: 1.292183
# Warning in density fit -- large error: 1.292183
# Warning in density fit -- large error: 1.292183
# Warning in density fit -- large error: 1.293211
# Warning in density fit -- large error: 1.293211
# Warning in density fit -- large error: 1.293211
# Warning in density fit -- large error: 1.314726
# Warning in density fit -- large error: 1.314726
# Warning in density fit -- large error: 1.314726
# Warning in density fit -- large error: 1.335199
# Warning in density fit -- large error: 1.335199
# Warning in density fit -- large error: 1.335199
# Warning in density fit -- large error: 1.328169
# Warning in density fit -- large error: 1.328169
# Warning in density fit -- large error: 1.328169
# Warning in density fit -- large error: 2.895156
# Warning in density fit -- large error: 2.895156
# Warning in density fit -- large error: 2.895156
# Warning in density fit -- large error: 2.894502
# Warning in density fit -- large error: 2.894502
# Warning in density fit -- large error: 2.894502
# Warning in density fit -- large error: 2.855933
# Warning in density fit -- large error: 2.855933
# Warning in density fit -- large error: 2.855933
# Warning in density fit -- large error: 1.346535
# Warning in density fit -- large error: 1.346535
# Warning in density fit -- large error: 1.346535
# Warning in density fit -- large error: 1.339500
# Warning in density fit -- large error: 1.339500
# Warning in density fit -- large error: 1.339500
# Warning in density fit -- large error: 1.347244
# Warning in density fit -- large error: 1.347244
# Warning in density fit -- large error: 1.347244
# Warning in density fit -- large error: 1.373238
# Warning in density fit -- large error: 1.373238
# Warning in density fit -- large error: 1.373238
# Warning in density fit -- large error: 1.352698
# Warning in density fit -- large error: 1.352698
# Warning in density fit -- large error: 1.352698
# Warning in density fit -- large error: 1.336613
# Warning in density fit -- large error: 1.336613
# Warning in density fit -- large error: 1.336613
# Warning in density fit -- large error: 1.351134
# Warning in density fit -- large error: 1.351134
# Warning in density fit -- large error: 1.351134
# Warning in density fit -- large error: 1.356867
# Warning in density fit -- large error: 1.356867
# Warning in density fit -- large error: 1.356867
# Warning in density fit -- large error: 1.325717
# Warning in density fit -- large error: 1.325717
# Warning in density fit -- large error: 1.325717
# Warning in density fit -- large error: 1.293271
# Warning in density fit -- large error: 1.293271
# Warning in density fit -- large error: 1.293271
# Warning in density fit -- large error: 1.275193
# Warning in density fit -- large error: 1.275193
# Warning in density fit -- large error: 1.275193
# Warning in density fit -- large error: 1.300655
# Warning in density fit -- large error: 1.300655
# Warning in density fit -- large error: 1.300655
# Warning in density fit -- large error: 1.301202
# Warning in density fit -- large error: 1.301202
# Warning in density fit -- large error: 1.301202
# Warning in density fit -- large error: 1.296752
# Warning in density fit -- large error: 1.296752
# Warning in density fit -- large error: 1.296752
# Warning in density fit -- large error: 1.282331
# Warning in density fit -- large error: 1.282331
# Warning in density fit -- large error: 1.282331
# Warning in density fit -- large error: 1.296880
# Warning in density fit -- large error: 1.296880
# Warning in density fit -- large error: 1.296880
# Warning in density fit -- large error: 1.303192
# Warning in density fit -- large error: 1.303192
# Warning in density fit -- large error: 1.303192
# Warning in density fit -- large error: 1.284865
# Warning in density fit -- large error: 1.284865
# Warning in density fit -- large error: 1.284865
# Warning in density fit -- large error: 1.245741
# Warning in density fit -- large error: 1.245741
# Warning in density fit -- large error: 1.245741
# Warning in density fit -- large error: 1.211813
# Warning in density fit -- large error: 1.211813
# Warning in density fit -- large error: 1.211813
# Warning in density fit -- large error: 1.217652
# Warning in density fit -- large error: 1.217652
# Warning in density fit -- large error: 1.217652
# Warning in density fit -- large error: 1.206612
# Warning in density fit -- large error: 1.206612
# Warning in density fit -- large error: 1.206612
# Warning in density fit -- large error: 1.202459
# Warning in density fit -- large error: 1.202459
# Warning in density fit -- large error: 1.202459
# Warning in density fit -- large error: 1.178744
# Warning in density fit -- large error: 1.178744
# Warning in density fit -- large error: 1.178744
# Warning in density fit -- large error: 1.183053
# Warning in density fit -- large error: 1.183053
# Warning in density fit -- large error: 1.183053
# Warning in density fit -- large error: 1.149626
# Warning in density fit -- large error: 1.149626
# Warning in density fit -- large error: 1.149626
# Warning in density fit -- large error: 1.102486
# Warning in density fit -- large error: 1.102486
# Warning in density fit -- large error: 1.102486
# Warning in density fit -- large error: 1.463570
# Warning in density fit -- large error: 1.463570
# Warning in density fit -- large error: 1.463570
# Warning in density fit -- large error: 1.401648
# Warning in density fit -- large error: 1.401648
# Warning in density fit -- large error: 1.401648
# Warning in density fit -- large error: 1.715725
# Warning in density fit -- large error: 1.715725
# Warning in density fit -- large error: 1.715725
# Warning in density fit -- large error: 1.131503
# Warning in density fit -- large error: 1.131503
# Warning in density fit -- large error: 1.131503
# Warning in density fit -- large error: 1.185086
# Warning in density fit -- large error: 1.185086
# Warning in density fit -- large error: 1.185086
# Warning in density fit -- large error: 1.194694
# Warning in density fit -- large error: 1.194694
# Warning in density fit -- large error: 1.194694
# Warning in density fit -- large error: 1.222459
# Warning in density fit -- large error: 1.222459
# Warning in density fit -- large error: 1.222459
# Warning in density fit -- large error: 1.240494
# Warning in density fit -- large error: 1.240494
# Warning in density fit -- large error: 1.240494
# Warning in density fit -- large error: 1.243822
# Warning in density fit -- large error: 1.243822
# Warning in density fit -- large error: 1.243822
# Warning in density fit -- large error: 1.270489
# Warning in density fit -- large error: 1.270489
# Warning in density fit -- large error: 1.270489
# Warning in density fit -- large error: 1.313850
# Warning in density fit -- large error: 1.313850
# Warning in density fit -- large error: 1.313850
# Warning in density fit -- large error: 1.374347
# Warning in density fit -- large error: 1.374347
# Warning in density fit -- large error: 1.374347
# Warning in density fit -- large error: 1.398521
# Warning in density fit -- large error: 1.398521
# Warning in density fit -- large error: 1.398521
# Warning in density fit -- large error: 1.385979
# Warning in density fit -- large error: 1.385979
# Warning in density fit -- large error: 1.385979
# Warning in density fit -- large error: 1.395407
# Warning in density fit -- large error: 1.395407
# Warning in density fit -- large error: 1.395407
# Warning in density fit -- large error: 1.437134
# Warning in density fit -- large error: 1.437134
# Warning in density fit -- large error: 1.437134
# Warning in density fit -- large error: 1.429252
# Warning in density fit -- large error: 1.429252
# Warning in density fit -- large error: 1.429252
# Warning in density fit -- large error: 1.426360
# Warning in density fit -- large error: 1.426360
# Warning in density fit -- large error: 1.426360
# Warning in density fit -- large error: 1.423200
# Warning in density fit -- large error: 1.423200
# Warning in density fit -- large error: 1.423200
# Warning in density fit -- large error: 1.431931
# Warning in density fit -- large error: 1.431931
# Warning in density fit -- large error: 1.431931
# Warning in density fit -- large error: 1.122558
# Warning in density fit -- large error: 1.122558
# Warning in density fit -- large error: 1.122558
# Warning in density fit -- large error: 1.412043
# Warning in density fit -- large error: 1.412043
# Warning in density fit -- large error: 1.412043
# Warning in density fit -- large error: 1.399600
# Warning in density fit -- large error: 1.399600
# Warning in density fit -- large error: 1.399600
# Warning in density fit -- large error: 1.410902
# Warning in density fit -- large error: 1.410902
# Warning in density fit -- large error: 1.410902
# Warning in density fit -- large error: 1.424424
# Warning in density fit -- large error: 1.424424
# Warning in density fit -- large error: 1.424424
# Warning in density fit -- large error: 1.420985
# Warning in density fit -- large error: 1.420985
# Warning in density fit -- large error: 1.420985
# Warning in density fit -- large error: 1.415240
# Warning in density fit -- large error: 1.415240
# Warning in density fit -- large error: 1.415240
# Warning in density fit -- large error: 1.398401
# Warning in density fit -- large error: 1.398401
# Warning in density fit -- large error: 1.398401
# Warning in density fit -- large error: 1.338932
# Warning in density fit -- large error: 1.338932
# Warning in density fit -- large error: 1.338932
# Warning in density fit -- large error: 1.339166
# Warning in density fit -- large error: 1.339166
# Warning in density fit -- large error: 1.339166
# Warning in density fit -- large error: 1.348262
# Warning in density fit -- large error: 1.348262
# Warning in density fit -- large error: 1.348262
# Warning in density fit -- large error: 1.345460
# Warning in density fit -- large error: 1.345460
# Warning in density fit -- large error: 1.345460
# Warning in density fit -- large error: 1.362355
# Warning in density fit -- large error: 1.362355
# Warning in density fit -- large error: 1.362355
# Warning in density fit -- large error: 1.543049
# Warning in density fit -- large error: 1.543049
# Warning in density fit -- large error: 1.543049
# Warning in density fit -- large error: 1.371231
# Warning in density fit -- large error: 1.371231
# Warning in density fit -- large error: 1.371231
# Warning in density fit -- large error: 1.375019
# Warning in density fit -- large error: 1.375019
# Warning in density fit -- large error: 1.375019
# Warning in density fit -- large error: 1.346305
# Warning in density fit -- large error: 1.346305
# Warning in density fit -- large error: 1.346305
# Warning in density fit -- large error: 1.326457
# Warning in density fit -- large error: 1.326457
# Warning in density fit -- large error: 1.326457
# Warning in density fit -- large error: 1.329668
# Warning in density fit -- large error: 1.329668
# Warning in density fit -- large error: 1.329668
# Warning in density fit -- large error: 1.344435
# Warning in density fit -- large error: 1.344435
# Warning in density fit -- large error: 1.344435
# Warning in density fit -- large error: 1.349531
# Warning in density fit -- large error: 1.349531
# Warning in density fit -- large error: 1.349531
# Warning in density fit -- large error: 1.365962
# Warning in density fit -- large error: 1.365962
# Warning in density fit -- large error: 1.365962
# Warning in density fit -- large error: 1.346602
# Warning in density fit -- large error: 1.346602
# Warning in density fit -- large error: 1.346602
# Warning in density fit -- large error: 1.330024
# Warning in density fit -- large error: 1.330024
# Warning in density fit -- large error: 1.330024
# Warning in density fit -- large error: 1.315394
# Warning in density fit -- large error: 1.315394
# Warning in density fit -- large error: 1.315394
# Warning in density fit -- large error: 1.324403
# Warning in density fit -- large error: 1.324403
# Warning in density fit -- large error: 1.324403
# Warning in density fit -- large error: 1.324943
# Warning in density fit -- large error: 1.324943
# Warning in density fit -- large error: 1.324943
# Warning in density fit -- large error: 1.325683
# Warning in density fit -- large error: 1.325683
# Warning in density fit -- large error: 1.325683
# Warning in density fit -- large error: 1.316488
# Warning in density fit -- large error: 1.316488
# Warning in density fit -- large error: 1.316488
# Warning in density fit -- large error: 1.312736
# Warning in density fit -- large error: 1.312736
# Warning in density fit -- large error: 1.312736
# Warning in density fit -- large error: 1.309990
# Warning in density fit -- large error: 1.309990
# Warning in density fit -- large error: 1.309990
# Warning in density fit -- large error: 1.169701
# Warning in density fit -- large error: 1.169701
# Warning in density fit -- large error: 1.169701
# Warning in density fit -- large error: 1.325208
# Warning in density fit -- large error: 1.325208
# Warning in density fit -- large error: 1.325208
# Warning in density fit -- large error: 1.278921
# Warning in density fit -- large error: 1.278921
# Warning in density fit -- large error: 1.278921
# Warning in density fit -- large error: 1.237334
# Warning in density fit -- large error: 1.237334
# Warning in density fit -- large error: 1.237334
# Warning in density fit -- large error: 1.227598
# Warning in density fit -- large error: 1.227598
# Warning in density fit -- large error: 1.227598
# Warning in density fit -- large error: 1.209386
# Warning in density fit -- large error: 1.209386
# Warning in density fit -- large error: 1.209386
# Warning in density fit -- large error: 1.194653
# Warning in density fit -- large error: 1.194653
# Warning in density fit -- large error: 1.194653
# Warning in density fit -- large error: 1.189562
# Warning in density fit -- large error: 1.189562
# Warning in density fit -- large error: 1.189562
# Warning in density fit -- large error: 1.213512
# Warning in density fit -- large error: 1.213512
# Warning in density fit -- large error: 1.213512
# Warning in density fit -- large error: 1.344855
# Warning in density fit -- large error: 1.344855
# Warning in density fit -- large error: 1.344855
# Warning in density fit -- large error: 1.201925
# Warning in density fit -- large error: 1.201925
# Warning in density fit -- large error: 1.201925
# Warning in density fit -- large error: 1.149088
# Warning in density fit -- large error: 1.149088
# Warning in density fit -- large error: 1.149088
# Warning in density fit -- large error: 1.446133
# Warning in density fit -- large error: 1.446133
# Warning in density fit -- large error: 1.446133
# Warning in density fit -- large error: 1.100433
# Warning in density fit -- large error: 1.100433
# Warning in density fit -- large error: 1.100433
# Warning in density fit -- large error: 1.673133
# Warning in density fit -- large error: 1.673133
# Warning in density fit -- large error: 1.673133
# Warning in density fit -- large error: 1.106916
# Warning in density fit -- large error: 1.106916
# Warning in density fit -- large error: 1.106916
# Warning in density fit -- large error: 1.149236
# Warning in density fit -- large error: 1.149236
# Warning in density fit -- large error: 1.149236
# Warning in density fit -- large error: 1.153394
# Warning in density fit -- large error: 1.153394
# Warning in density fit -- large error: 1.153394
# Warning in density fit -- large error: 1.173625
# Warning in density fit -- large error: 1.173625
# Warning in density fit -- large error: 1.173625
# Warning in density fit -- large error: 1.213256
# Warning in density fit -- large error: 1.213256
# Warning in density fit -- large error: 1.213256
# Warning in density fit -- large error: 1.220494
# Warning in density fit -- large error: 1.220494
# Warning in density fit -- large error: 1.220494
# Warning in density fit -- large error: 1.221201
# Warning in density fit -- large error: 1.221201
# Warning in density fit -- large error: 1.221201
# Warning in density fit -- large error: 1.234427
# Warning in density fit -- large error: 1.234427
# Warning in density fit -- large error: 1.234427
# Warning in density fit -- large error: 1.262332
# Warning in density fit -- large error: 1.262332
# Warning in density fit -- large error: 1.262332
# Warning in density fit -- large error: 1.285206
# Warning in density fit -- large error: 1.285206
# Warning in density fit -- large error: 1.285206
# Warning in density fit -- large error: 1.279135
# Warning in density fit -- large error: 1.279135
# Warning in density fit -- large error: 1.279135
# Warning in density fit -- large error: 1.303490
# Warning in density fit -- large error: 1.303490
# Warning in density fit -- large error: 1.303490
# Warning in density fit -- large error: 1.341506
# Warning in density fit -- large error: 1.341506
# Warning in density fit -- large error: 1.341506
# Warning in density fit -- large error: 1.365819
# Warning in density fit -- large error: 1.365819
# Warning in density fit -- large error: 1.365819
# Warning in density fit -- large error: 1.391188
# Warning in density fit -- large error: 1.391188
# Warning in density fit -- large error: 1.391188
# Warning in density fit -- large error: 1.405656
# Warning in density fit -- large error: 1.405656
# Warning in density fit -- large error: 1.405656
# Warning in density fit -- large error: 1.423701
# Warning in density fit -- large error: 1.423701
# Warning in density fit -- large error: 1.423701
# Warning in density fit -- large error: 1.409435
# Warning in density fit -- large error: 1.409435
# Warning in density fit -- large error: 1.409435
# Warning in density fit -- large error: 1.387144
# Warning in density fit -- large error: 1.387144
# Warning in density fit -- large error: 1.387144
# Warning in density fit -- large error: 1.367903
# Warning in density fit -- large error: 1.367903
# Warning in density fit -- large error: 1.367903
# Warning in density fit -- large error: 1.369006
# Warning in density fit -- large error: 1.369006
# Warning in density fit -- large error: 1.369006
# Warning in density fit -- large error: 1.362629
# Warning in density fit -- large error: 1.362629
# Warning in density fit -- large error: 1.362629
# Warning in density fit -- large error: 1.361106
# Warning in density fit -- large error: 1.361106
# Warning in density fit -- large error: 1.361106
# Warning in density fit -- large error: 1.367233
# Warning in density fit -- large error: 1.367233
# Warning in density fit -- large error: 1.367233
# Warning in density fit -- large error: 1.362782
# Warning in density fit -- large error: 1.362782
# Warning in density fit -- large error: 1.362782
# Warning in density fit -- large error: 1.315371
# Warning in density fit -- large error: 1.315371
# Warning in density fit -- large error: 1.315371
# Warning in density fit -- large error: 1.314033
# Warning in density fit -- large error: 1.314033
# Warning in density fit -- large error: 1.314033
# Warning in density fit -- large error: 1.299154
# Warning in density fit -- large error: 1.299154
# Warning in density fit -- large error: 1.299154
# Warning in density fit -- large error: 1.292000
# Warning in density fit -- large error: 1.292000
# Warning in density fit -- large error: 1.292000
# Warning in density fit -- large error: 1.301587
# Warning in density fit -- large error: 1.301587
# Warning in density fit -- large error: 1.301587
# Warning in density fit -- large error: 1.304578
# Warning in density fit -- large error: 1.304578
# Warning in density fit -- large error: 1.304578
# Warning in density fit -- large error: 1.293914
# Warning in density fit -- large error: 1.293914
# Warning in density fit -- large error: 1.293914
# Warning in density fit -- large error: 1.263955
# Warning in density fit -- large error: 1.263955
# Warning in density fit -- large error: 1.263955
# Warning in density fit -- large error: 1.217757
# Warning in density fit -- large error: 1.217757
# Warning in density fit -- large error: 1.217757
# Warning in density fit -- large error: 1.226994
# Warning in density fit -- large error: 1.226994
# Warning in density fit -- large error: 1.226994
# Warning in density fit -- large error: 1.201069
# Warning in density fit -- large error: 1.201069
# Warning in density fit -- large error: 1.201069
# Warning in density fit -- large error: 1.178881
# Warning in density fit -- large error: 1.178881
# Warning in density fit -- large error: 1.178881
# Warning in density fit -- large error: 1.153598
# Warning in density fit -- large error: 1.153598
# Warning in density fit -- large error: 1.153598
# Warning in density fit -- large error: 1.105665
# Warning in density fit -- large error: 1.105665
# Warning in density fit -- large error: 1.105665
# Warning in density fit -- large error: 1.250974
# Warning in density fit -- large error: 1.250974
# Warning in density fit -- large error: 1.250974
# Warning in density fit -- large error: 1.222915
# Warning in density fit -- large error: 1.222915
# Warning in density fit -- large error: 1.222915
# Warning in density fit -- large error: 1.241776
# Warning in density fit -- large error: 1.241776
# Warning in density fit -- large error: 1.241776
# Warning in density fit -- large error: 1.273583
# Warning in density fit -- large error: 1.273583
# Warning in density fit -- large error: 1.273583
# Warning in density fit -- large error: 1.299832
# Warning in density fit -- large error: 1.299832
# Warning in density fit -- large error: 1.299832
# Warning in density fit -- large error: 1.320773
# Warning in density fit -- large error: 1.320773
# Warning in density fit -- large error: 1.320773
# Warning in density fit -- large error: 1.248352
# Warning in density fit -- large error: 1.248352
# Warning in density fit -- large error: 1.248352
# Warning in density fit -- large error: 2.432953
# Warning in density fit -- large error: 2.432953
# Warning in density fit -- large error: 2.432953
# Warning in density fit -- large error: 2.463965
# Warning in density fit -- large error: 2.463965
# Warning in density fit -- large error: 2.463965
# Warning in density fit -- large error: 2.511806
# Warning in density fit -- large error: 2.511806
# Warning in density fit -- large error: 2.511806
# Warning in density fit -- large error: 2.459131
# Warning in density fit -- large error: 2.459131
# Warning in density fit -- large error: 2.459131
# Warning in density fit -- large error: 2.368672
# Warning in density fit -- large error: 2.368672
# Warning in density fit -- large error: 2.368672
# Warning in density fit -- large error: 2.306926
# Warning in density fit -- large error: 2.306926
# Warning in density fit -- large error: 2.306926
# Warning in density fit -- large error: 2.366657
# Warning in density fit -- large error: 2.366657
# Warning in density fit -- large error: 2.366657
# Warning in density fit -- large error: 2.320471
# Warning in density fit -- large error: 2.320471
# Warning in density fit -- large error: 2.320471
# Warning in density fit -- large error: 2.304426
# Warning in density fit -- large error: 2.304426
# Warning in density fit -- large error: 2.304426
# Warning in density fit -- large error: 1.299264
# Warning in density fit -- large error: 1.299264
# Warning in density fit -- large error: 1.299264
# Warning in density fit -- large error: 1.116266
# Warning in density fit -- large error: 1.116266
# Warning in density fit -- large error: 1.116266
# Done
# lv2 to lv3 processing done
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "title" to "Level 3 process file made from level 2 stacked mooring"
# Setting attribute "institution" to "The University of Western Australia"
# Setting attribute "institution_division" to "Ocean Dynamics"
# Setting attribute "source" to "pIMOS"
# Setting attribute "project" to "AIMS"
# Setting attribute "history" to ""
# Setting attribute "references" to ""
# Setting attribute "comment" to ""
# Setting attribute "Conventions" to "CF-1.7"
# Setting attribute "trip" to "6/05/2011"
# Setting attribute "trip_deployed" to "ITFTIS-1101;ITFTIS-1101;ITFTIS-1101;ITFTIS-1101;ITFTIS-1101;ITFTIS-1101;ITFTIS-1101;ITFTIS-1101;ITFTIS-1101;ITFTIS-1101;ITFTIS-1101"
# Setting attribute "site" to "ITFTIS"
# Setting attribute "site_station" to "ITFTIS"
# Setting attribute "instrument_make" to "SEABIRD SBE37SMP + P;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE PRESSURE - TDR-2050;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE LOGGER TR-1060P;SEABIRD SBE37SM + P;BRANCKER TEMPERATURE LOGGER TR-1060P;SEABIRD SBE37SMP + P;BRANCKER TEMPERATURE PRESSURE - TDR-2050;REEFNET SENSUS ULTRA"
# Setting attribute "instrument_model" to "SEABIRD SBE37SMP + P;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE PRESSURE - TDR-2050;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE LOGGER TR-1060P;SEABIRD SBE37SM + P;BRANCKER TEMPERATURE LOGGER TR-1060P;SEABIRD SBE37SMP + P;BRANCKER TEMPERATURE PRESSURE - TDR-2050;REEFNET SENSUS ULTRA"
# Setting attribute "instrument_serial_number" to "8050;20176;20167;16254;20168;20188;4481;20129;7882;16245;08480"
# Setting attribute "raw_file_name" to "6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011"
# Setting attribute "raw_file_directory" to "6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011"
# Setting attribute "raw_file_attributes" to "6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011;6/05/2011"
# Setting attribute "last_export_file_name" to ""
# Setting attribute "last_export_directory" to ""
# Setting attribute "last_load_file_name" to ""
# Setting attribute "last_load_directory" to ""
# Setting attribute "outfile_append" to ""
# Setting attribute "disclaimer" to "Data, products and services from IMOS are provided "as is" without any warranty as to fitness for a particular purpose."
# Setting attribute "nominal_latitude" to "-9.8168333333"
# Setting attribute "nominal_longitude" to "127.5531333333"
# Setting attribute "nominal_site_depth" to "465.0"
# Setting attribute "pressure_sensor_height_asb" to ""
# Setting attribute "nominal_instrument_height_asb" to "100.0;130.0;170.0;20.0;270.0;370.0;40.0;461.0;60.0;80.0;9.0"
# Setting attribute "nominal_instrument_orientation" to ""
# Setting attribute "timezone" to "2011-01-08"
# Setting attribute "process_level" to "3"
# Setting attribute "is_profile_data" to "0"
# Level 3 process file made from level 2 stacked mooring
# Level 3 process file made from level 2 stacked mooring
# pIMOS
# pIMOS
# 3
# 3
# Filling nans in Temperature
# Done.
# Calculating Salinity
# Done
# Calculating Density
# Pressure estimated from nominal depth.
# Done
# Creating slow time
# Done
# Calculating buoyancy modes
# C:\Users\21924032\GitHub\Normal-Mode-Decomposition-of-the-Internal-Wave\pIMOS_Tao\pIMOS\xrwrap\pl3_stacked_mooring.py:191: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   self.ds['timeslow'] = timeslow
# C:\Users\21924032\GitHub\Normal-Mode-Decomposition-of-the-Internal-Wave\pIMOS_Tao\pIMOS\xrwrap\pl3_stacked_mooring.py:191: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   self.ds['timeslow'] = timeslow
# Warning in density fit -- large error: 1.153691
# Warning in density fit -- large error: 1.153691
# Warning in density fit -- large error: 1.153691
# Warning in density fit -- large error: 1.150182
# Warning in density fit -- large error: 1.150182
# Warning in density fit -- large error: 1.150182
# Warning in density fit -- large error: 1.155627
# Warning in density fit -- large error: 1.155627
# Warning in density fit -- large error: 1.155627
# Warning in density fit -- large error: 1.181415
# Warning in density fit -- large error: 1.181415
# Warning in density fit -- large error: 1.181415
# Warning in density fit -- large error: 1.219831
# Warning in density fit -- large error: 1.219831
# Warning in density fit -- large error: 1.219831
# Warning in density fit -- large error: 1.200140
# Warning in density fit -- large error: 1.200140
# Warning in density fit -- large error: 1.200140
# Warning in density fit -- large error: 1.186027
# Warning in density fit -- large error: 1.186027
# Warning in density fit -- large error: 1.186027
# Warning in density fit -- large error: 1.178422
# Warning in density fit -- large error: 1.178422
# Warning in density fit -- large error: 1.178422
# Warning in density fit -- large error: 1.210618
# Warning in density fit -- large error: 1.210618
# Warning in density fit -- large error: 1.210618
# Warning in density fit -- large error: 1.174930
# Warning in density fit -- large error: 1.174930
# Warning in density fit -- large error: 1.174930
# Warning in density fit -- large error: 1.122588
# Warning in density fit -- large error: 1.122588
# Warning in density fit -- large error: 1.122588
# Warning in density fit -- large error: 1.172974
# Warning in density fit -- large error: 1.172974
# Warning in density fit -- large error: 1.172974
# Warning in density fit -- large error: 1.130070
# Warning in density fit -- large error: 1.130070
# Warning in density fit -- large error: 1.130070
# Warning in density fit -- large error: 1.113166
# Warning in density fit -- large error: 1.113166
# Warning in density fit -- large error: 1.113166
# Warning in density fit -- large error: 1.171440
# Warning in density fit -- large error: 1.171440
# Warning in density fit -- large error: 1.171440
# Warning in density fit -- large error: 1.164086
# Warning in density fit -- large error: 1.164086
# Warning in density fit -- large error: 1.164086
# Warning in density fit -- large error: 1.161427
# Warning in density fit -- large error: 1.161427
# Warning in density fit -- large error: 1.161427
# Warning in density fit -- large error: 1.231727
# Warning in density fit -- large error: 1.231727
# Warning in density fit -- large error: 1.231727
# Warning in density fit -- large error: 1.245942
# Warning in density fit -- large error: 1.245942
# Warning in density fit -- large error: 1.245942
# Warning in density fit -- large error: 1.289615
# Warning in density fit -- large error: 1.289615
# Warning in density fit -- large error: 1.289615
# Warning in density fit -- large error: 1.293219
# Warning in density fit -- large error: 1.293219
# Warning in density fit -- large error: 1.293219
# Warning in density fit -- large error: 1.320474
# Warning in density fit -- large error: 1.320474
# Warning in density fit -- large error: 1.320474
# Warning in density fit -- large error: 1.311691
# Warning in density fit -- large error: 1.311691
# Warning in density fit -- large error: 1.311691
# Done
# lv2 to lv3 processing done
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "title" to "Level 3 process file made from level 2 stacked mooring"
# Setting attribute "institution" to "The University of Western Australia"
# Setting attribute "institution_division" to "Ocean Dynamics"
# Setting attribute "source" to "pIMOS"
# Setting attribute "project" to "AIMS"
# Setting attribute "history" to ""
# Setting attribute "references" to ""
# Setting attribute "comment" to ""
# Setting attribute "Conventions" to "CF-1.7"
# Setting attribute "trip" to "0/01/2012"
# Setting attribute "trip_deployed" to "ITFTIS-1105;ITFTIS-1105;ITFTIS-1105;ITFTIS-1105;ITFTIS-1105;ITFTIS-1105;ITFTIS-1105;ITFTIS-1105;ITFTIS-1105;ITFTIS-1105;ITFTIS-1105;ITFTIS-1105;ITFTIS-1105;ITFTIS-1105;ITFTIS-1105;ITFTIS-1105;ITFTIS-1105"
# Setting attribute "site" to "ITFTIS"
# Setting attribute "site_station" to "ITFTIS"
# Setting attribute "instrument_make" to "SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39 - TEMPERATURE RECORDER;BRANCKER TEMPERATURE PRESSURE - TDR-2050;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39 - TEMPERATURE RECORDER;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE PRESSURE - TDR-2050;BRANCKER TEMPERATURE LOGGER TR-1060P;SEABIRD SBE37SM + P;BRANCKER TEMPERATURE LOGGER TR-1060P;SEABIRD SBE39 - TEMPERATURE RECORDER;BRANCKER TEMPERATURE LOGGER TR-1060P;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE37SM + P"
# Setting attribute "instrument_model" to "SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39 - TEMPERATURE RECORDER;BRANCKER TEMPERATURE PRESSURE - TDR-2050;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39 - TEMPERATURE RECORDER;BRANCKER TEMPERATURE LOGGER TR-1060P;BRANCKER TEMPERATURE PRESSURE - TDR-2050;BRANCKER TEMPERATURE LOGGER TR-1060P;SEABIRD SBE37SM + P;BRANCKER TEMPERATURE LOGGER TR-1060P;SEABIRD SBE39 - TEMPERATURE RECORDER;BRANCKER TEMPERATURE LOGGER TR-1060P;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE37SM + P"
# Setting attribute "instrument_serial_number" to "3750;0675;16243;3752;0917;0922;20172;16245;20129;4477;20167;3747;20168;4479;3749;4480;4481"
# Setting attribute "raw_file_name" to "0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012"
# Setting attribute "raw_file_directory" to "0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012"
# Setting attribute "raw_file_attributes" to "0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012;0/01/2012"
# Setting attribute "last_export_file_name" to ""
# Setting attribute "last_export_directory" to ""
# Setting attribute "last_load_file_name" to ""
# Setting attribute "last_load_directory" to ""
# Setting attribute "outfile_append" to ""
# Setting attribute "disclaimer" to "Data, products and services from IMOS are provided "as is" without any warranty as to fitness for a particular purpose."
# Setting attribute "nominal_latitude" to "-9.8175833333"
# Setting attribute "nominal_longitude" to "127.5539666667"
# Setting attribute "nominal_site_depth" to "460.7"
# Setting attribute "pressure_sensor_height_asb" to ""
# Setting attribute "nominal_instrument_height_asb" to "110.7;125.7;15.7;150.7;175.7;195.7;245.7;25.7;295.7;35.7;395.7;45.7;456.7;55.7;65.7;75.7;95.7"
# Setting attribute "nominal_instrument_orientation" to ""
# Setting attribute "timezone" to "2011-05-30"
# Setting attribute "process_level" to "3"
# Setting attribute "is_profile_data" to "0"
# Level 3 process file made from level 2 stacked mooring
# Level 3 process file made from level 2 stacked mooring
# pIMOS
# pIMOS
# 3
# 3
# Too many nan appearing at TEMP!! check depths at [-125.7]
# Filling nans in Temperature
# Done.
# Calculating Salinity
# Done
# Calculating Density
# Pressure estimated from nominal depth.
# Done
# Creating slow time
# Done
# Calculating buoyancy modes
# C:\Users\21924032\GitHub\Normal-Mode-Decomposition-of-the-Internal-Wave\pIMOS_Tao\pIMOS\xrwrap\pl3_stacked_mooring.py:191: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   self.ds['timeslow'] = timeslow
# C:\Users\21924032\GitHub\Normal-Mode-Decomposition-of-the-Internal-Wave\pIMOS_Tao\pIMOS\xrwrap\pl3_stacked_mooring.py:191: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   self.ds['timeslow'] = timeslow
# Warning in density fit -- large error: 1.106263
# Warning in density fit -- large error: 1.106263
# Warning in density fit -- large error: 1.106263
# Warning in density fit -- large error: 1.104542
# Warning in density fit -- large error: 1.104542
# Warning in density fit -- large error: 1.104542
# Warning in density fit -- large error: 1.113943
# Warning in density fit -- large error: 1.113943
# Warning in density fit -- large error: 1.113943
# Warning in density fit -- large error: 1.139849
# Warning in density fit -- large error: 1.139849
# Warning in density fit -- large error: 1.139849
# Warning in density fit -- large error: 1.203917
# Warning in density fit -- large error: 1.203917
# Warning in density fit -- large error: 1.203917
# Warning in density fit -- large error: 1.517636
# Warning in density fit -- large error: 1.517636
# Warning in density fit -- large error: 1.517636
# Warning in density fit -- large error: 1.560937
# Warning in density fit -- large error: 1.560937
# Warning in density fit -- large error: 1.560937
# Warning in density fit -- large error: 1.127797
# Warning in density fit -- large error: 1.127797
# Warning in density fit -- large error: 1.127797
# Warning in density fit -- large error: 1.774794
# Warning in density fit -- large error: 1.774794
# Warning in density fit -- large error: 1.774794
# Warning in density fit -- large error: 1.788137
# Warning in density fit -- large error: 1.788137
# Warning in density fit -- large error: 1.788137
# Warning in density fit -- large error: 1.110057
# Warning in density fit -- large error: 1.110057
# Warning in density fit -- large error: 1.110057
# Warning in density fit -- large error: 1.122644
# Warning in density fit -- large error: 1.122644
# Warning in density fit -- large error: 1.122644
# Warning in density fit -- large error: 1.128909
# Warning in density fit -- large error: 1.128909
# Warning in density fit -- large error: 1.128909
# Warning in density fit -- large error: 1.140703
# Warning in density fit -- large error: 1.140703
# Warning in density fit -- large error: 1.140703
# Warning in density fit -- large error: 1.126868
# Warning in density fit -- large error: 1.126868
# Warning in density fit -- large error: 1.126868
# Warning in density fit -- large error: 1.117167
# Warning in density fit -- large error: 1.117167
# Warning in density fit -- large error: 1.117167
# Warning in density fit -- large error: 1.104620
# Warning in density fit -- large error: 1.104620
# Warning in density fit -- large error: 1.104620
# Warning in density fit -- large error: 1.134334
# Warning in density fit -- large error: 1.134334
# Warning in density fit -- large error: 1.134334
# Warning in density fit -- large error: 1.140961
# Warning in density fit -- large error: 1.140961
# Warning in density fit -- large error: 1.140961
# Warning in density fit -- large error: 1.111545
# Warning in density fit -- large error: 1.111545
# Warning in density fit -- large error: 1.111545
# Warning in density fit -- large error: 1.121688
# Warning in density fit -- large error: 1.121688
# Warning in density fit -- large error: 1.121688
# Warning in density fit -- large error: 1.148664
# Warning in density fit -- large error: 1.148664
# Warning in density fit -- large error: 1.148664
# Warning in density fit -- large error: 1.171047
# Warning in density fit -- large error: 1.171047
# Warning in density fit -- large error: 1.171047
# Warning in density fit -- large error: 1.148570
# Warning in density fit -- large error: 1.148570
# Warning in density fit -- large error: 1.148570
# Warning in density fit -- large error: 1.126968
# Warning in density fit -- large error: 1.126968
# Warning in density fit -- large error: 1.126968
# Warning in density fit -- large error: 1.131500
# Warning in density fit -- large error: 1.131500
# Warning in density fit -- large error: 1.131500
# Warning in density fit -- large error: 1.144434
# Warning in density fit -- large error: 1.144434
# Warning in density fit -- large error: 1.144434
# Warning in density fit -- large error: 1.150336
# Warning in density fit -- large error: 1.150336
# Warning in density fit -- large error: 1.150336
# Warning in density fit -- large error: 1.138489
# Warning in density fit -- large error: 1.138489
# Warning in density fit -- large error: 1.138489
# Warning in density fit -- large error: 1.151027
# Warning in density fit -- large error: 1.151027
# Warning in density fit -- large error: 1.151027
# Warning in density fit -- large error: 1.147926
# Warning in density fit -- large error: 1.147926
# Warning in density fit -- large error: 1.147926
# Warning in density fit -- large error: 1.182250
# Warning in density fit -- large error: 1.182250
# Warning in density fit -- large error: 1.182250
# Warning in density fit -- large error: 1.158650
# Warning in density fit -- large error: 1.158650
# Warning in density fit -- large error: 1.158650
# Warning in density fit -- large error: 1.114131
# Warning in density fit -- large error: 1.114131
# Warning in density fit -- large error: 1.114131
# Warning in density fit -- large error: 1.104880
# Warning in density fit -- large error: 1.104880
# Warning in density fit -- large error: 1.104880
# Warning in density fit -- large error: 1.124223
# Warning in density fit -- large error: 1.124223
# Warning in density fit -- large error: 1.124223
# Warning in density fit -- large error: 1.121702
# Warning in density fit -- large error: 1.121702
# Warning in density fit -- large error: 1.121702
# Warning in density fit -- large error: 1.113576
# Warning in density fit -- large error: 1.113576
# Warning in density fit -- large error: 1.113576
# Warning in density fit -- large error: 1.102008
# Warning in density fit -- large error: 1.102008
# Warning in density fit -- large error: 1.102008
# Warning in density fit -- large error: 1.103636
# Warning in density fit -- large error: 1.103636
# Warning in density fit -- large error: 1.103636
# Warning in density fit -- large error: 1.104952
# Warning in density fit -- large error: 1.104952
# Warning in density fit -- large error: 1.104952
# Warning in density fit -- large error: 1.128807
# ...
#   self.ds['timeslow'] = timeslow
# Done
# lv2 to lv3 processing done
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "title" to "Level 3 process file made from level 2 stacked mooring"
# Setting attribute "institution" to "The University of Western Australia"
# Setting attribute "institution_division" to "Ocean Dynamics"
# Setting attribute "source" to "pIMOS"
# Setting attribute "project" to "AIMS"
# Setting attribute "history" to ""
# Setting attribute "references" to ""
# Setting attribute "comment" to ""
# Setting attribute "Conventions" to "CF-1.7"
# Setting attribute "trip" to "5/02/2013"
# Setting attribute "trip_deployed" to "PIL200-1301;PIL200-1301;PIL200-1301;PIL200-1301;PIL200-1301;PIL200-1301;PIL200-1301;PIL200-1301;PIL200-1301;PIL200-1301;PIL200-1301;PIL200-1301;PIL200-1301;PIL200-1301;PIL200-1301;PIL200-1301;PIL200-1301;PIL200-1301"
# Setting attribute "site" to "PIL200"
# Setting attribute "site_station" to "PIL200"
# Setting attribute "instrument_make" to "SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE56 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE37SM + P;SEABIRD SBE39P - TEMPERATURE & PRESSURE RECORDER;SEABIRD SBE37SMP;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39P - TEMPERATURE & PRESSURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER"
# Setting attribute "instrument_model" to "SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE56 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE37SM + P;SEABIRD SBE39P - TEMPERATURE & PRESSURE RECORDER;SEABIRD SBE37SMP;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39P - TEMPERATURE & PRESSURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER"
# Setting attribute "instrument_serial_number" to "8736;3731;8732;3730;3732;8755;3747;8757;01270;8731;8739;5837;9292;4885;8759;0759;8737;1523"
# Setting attribute "raw_file_name" to "5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013"
# Setting attribute "raw_file_directory" to "5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013"
# Setting attribute "raw_file_attributes" to "5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013;5/02/2013"
# Setting attribute "last_export_file_name" to ""
# Setting attribute "last_export_directory" to ""
# Setting attribute "last_load_file_name" to ""
# Setting attribute "last_load_directory" to ""
# Setting attribute "outfile_append" to ""
# Setting attribute "disclaimer" to "Data, products and services from IMOS are provided "as is" without any warranty as to fitness for a particular purpose."
# Setting attribute "nominal_latitude" to "-19.4355833333"
# Setting attribute "nominal_longitude" to "115.9155"
# Setting attribute "nominal_site_depth" to "206.0"
# Setting attribute "pressure_sensor_height_asb" to ""
# Setting attribute "nominal_instrument_height_asb" to "106.0;116.0;126.0;136.0;146.0;156.0;166.0;176.0;186.0;201.0;26.0;36.0;46.0;56.0;66.0;76.0;86.0;96.0"
# Setting attribute "nominal_instrument_orientation" to ""
# Setting attribute "timezone" to "2013-02-05"
# Setting attribute "process_level" to "3"
# Setting attribute "is_profile_data" to "0"
# Level 3 process file made from level 2 stacked mooring
# Level 3 process file made from level 2 stacked mooring
# pIMOS
# pIMOS
# 3
# 3
# Filling nans in Temperature
# Done.
# Calculating Salinity
# Done
# Calculating Density
# Pressure estimated from nominal depth.
# Done
# Creating slow time
# Done
# Calculating buoyancy modes
# C:\Users\21924032\GitHub\Normal-Mode-Decomposition-of-the-Internal-Wave\pIMOS_Tao\pIMOS\xrwrap\pl3_stacked_mooring.py:191: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   self.ds['timeslow'] = timeslow
# C:\Users\21924032\GitHub\Normal-Mode-Decomposition-of-the-Internal-Wave\pIMOS_Tao\pIMOS\xrwrap\pl3_stacked_mooring.py:191: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   self.ds['timeslow'] = timeslow
# Done
# lv2 to lv3 processing done
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "title" to "Level 3 process file made from level 2 stacked mooring"
# Setting attribute "institution" to "The University of Western Australia"
# Setting attribute "institution_division" to "Ocean Dynamics"
# Setting attribute "source" to "pIMOS"
# Setting attribute "project" to "AIMS"
# Setting attribute "history" to ""
# Setting attribute "references" to ""
# Setting attribute "comment" to ""
# Setting attribute "Conventions" to "CF-1.7"
# Setting attribute "trip" to " Aug 2013"
# Setting attribute "trip_deployed" to "PIL200-1307;PIL200-1307;PIL200-1307;PIL200-1307;PIL200-1307;PIL200-1307;PIL200-1307;PIL200-1307;PIL200-1307;PIL200-1307;PIL200-1307;PIL200-1307;PIL200-1307;PIL200-1307"
# Setting attribute "site" to "PIL200"
# Setting attribute "site_station" to "PIL200"
# Setting attribute "instrument_make" to "SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE37SMP;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39P - TEMPERATURE & PRESSURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER"
# Setting attribute "instrument_model" to "SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE37SMP;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39P - TEMPERATURE & PRESSURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER"
# Setting attribute "instrument_serial_number" to "8758;0932;1054;8749;1058;8747;9305;4481;0925;4478;0926;4666;4477;0930"
# Setting attribute "raw_file_name" to " Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013"
# Setting attribute "raw_file_directory" to " Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013"
# Setting attribute "raw_file_attributes" to " Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013; Aug 2013"
# Setting attribute "last_export_file_name" to ""
# Setting attribute "last_export_directory" to ""
# Setting attribute "last_load_file_name" to ""
# Setting attribute "last_load_directory" to ""
# Setting attribute "outfile_append" to ""
# Setting attribute "disclaimer" to "Data, products and services from IMOS are provided "as is" without any warranty as to fitness for a particular purpose."
# Setting attribute "nominal_latitude" to "-19.4354666667"
# Setting attribute "nominal_longitude" to "115.9150833333"
# Setting attribute "nominal_site_depth" to "206.0"
# Setting attribute "pressure_sensor_height_asb" to ""
# Setting attribute "nominal_instrument_height_asb" to "106.0;126.0;136.0;146.0;166.0;176.0;201.0;27.0;46.0;56.0;66.0;76.0;86.0;96.0"
# Setting attribute "nominal_instrument_orientation" to ""
# Setting attribute "timezone" to "2013-08-03"
# Setting attribute "process_level" to "3"
# Setting attribute "is_profile_data" to "0"
# Level 3 process file made from level 2 stacked mooring
# Level 3 process file made from level 2 stacked mooring
# pIMOS
# pIMOS
# 3
# 3
# Filling nans in Temperature
# Done.
# Calculating Salinity
# Done
# Calculating Density
# Pressure estimated from nominal depth.
# Done
# Creating slow time
# Done
# Calculating buoyancy modes
# C:\Users\21924032\GitHub\Normal-Mode-Decomposition-of-the-Internal-Wave\pIMOS_Tao\pIMOS\xrwrap\pl3_stacked_mooring.py:191: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   self.ds['timeslow'] = timeslow
# C:\Users\21924032\GitHub\Normal-Mode-Decomposition-of-the-Internal-Wave\pIMOS_Tao\pIMOS\xrwrap\pl3_stacked_mooring.py:191: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   self.ds['timeslow'] = timeslow
# Done
# lv2 to lv3 processing done
# Initialising accessor.
# STORING RAW FILE ATTRIBUTES
# Setting attribute "title" to "Level 3 process file made from level 2 stacked mooring"
# Setting attribute "institution" to "The University of Western Australia"
# Setting attribute "institution_division" to "Ocean Dynamics"
# Setting attribute "source" to "pIMOS"
# Setting attribute "project" to "AIMS"
# Setting attribute "history" to ""
# Setting attribute "references" to ""
# Setting attribute "comment" to ""
# Setting attribute "Conventions" to "CF-1.7"
# Setting attribute "trip" to " Feb 2014"
# Setting attribute "trip_deployed" to "PIL200-1402;PIL200-1402;PIL200-1402;PIL200-1402;PIL200-1402;PIL200-1402;PIL200-1402;PIL200-1402;PIL200-1402;PIL200-1402;PIL200-1402;PIL200-1402;PIL200-1402;PIL200-1402;PIL200-1402;PIL200-1402;PIL200-1402"
# Setting attribute "site" to "PIL200"
# Setting attribute "site_station" to "PIL200"
# Setting attribute "instrument_make" to "SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39P - TEMPERATURE & PRESSURE RECORDER;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SMP;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39P - TEMPERATURE & PRESSURE RECORDER;SEABIRD SBE37SMP;SEABIRD SBE39P - TEMPERATURE & PRESSURE RECORDER;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER"
# Setting attribute "instrument_model" to "SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39P - TEMPERATURE & PRESSURE RECORDER;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SMP;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE39P - TEMPERATURE & PRESSURE RECORDER;SEABIRD SBE37SMP;SEABIRD SBE39P - TEMPERATURE & PRESSURE RECORDER;SEABIRD SBE39 - TEMPERATURE RECORDER;SEABIRD SBE37SM + P;SEABIRD SBE39 - TEMPERATURE RECORDER"
# Setting attribute "instrument_serial_number" to "8744;0935;5850;0922;8752;0917;8750;0924;9290;8741;1523;5855;9305;5853;1058;8743;1061"
# Setting attribute "raw_file_name" to " Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014"
# Setting attribute "raw_file_directory" to " Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014"
# Setting attribute "raw_file_attributes" to " Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014; Feb 2014"
# Setting attribute "last_export_file_name" to ""
# Setting attribute "last_export_directory" to ""
# Setting attribute "last_load_file_name" to ""
# Setting attribute "last_load_directory" to ""
# Setting attribute "outfile_append" to ""
# Setting attribute "disclaimer" to "Data, products and services from IMOS are provided "as is" without any warranty as to fitness for a particular purpose."
# Setting attribute "nominal_latitude" to "-19.4353333333"
# Setting attribute "nominal_longitude" to "115.9154"
# Setting attribute "nominal_site_depth" to "208.0"
# Setting attribute "pressure_sensor_height_asb" to ""
# Setting attribute "nominal_instrument_height_asb" to "109.0;118.0;128.0;138.0;148.0;158.0;178.0;188.0;202.0;29.0;38.0;48.0;58.0;68.0;78.0;88.0;98.0"
# Setting attribute "nominal_instrument_orientation" to ""
# Setting attribute "timezone" to "2014-02-11"
# Setting attribute "process_level" to "3"
# Setting attribute "is_profile_data" to "0"
# Level 3 process file made from level 2 stacked mooring
# Level 3 process file made from level 2 stacked mooring
# pIMOS
# pIMOS
# 3
# 3
# Filling nans in Temperature
# Done.
# Calculating Salinity
# Done
# Calculating Density
# Pressure estimated from nominal depth.
# Done
# Creating slow time
# Done
# Calculating buoyancy modes
# C:\Users\21924032\GitHub\Normal-Mode-Decomposition-of-the-Internal-Wave\pIMOS_Tao\pIMOS\xrwrap\pl3_stacked_mooring.py:191: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   self.ds['timeslow'] = timeslow
# C:\Users\21924032\GitHub\Normal-Mode-Decomposition-of-the-Internal-Wave\pIMOS_Tao\pIMOS\xrwrap\pl3_stacked_mooring.py:191: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   self.ds['timeslow'] = timeslow
# Warning in density fit -- large error: 1.752244
# Warning in density fit -- large error: 1.752244
# Warning in density fit -- large error: 1.752244
# Done
# lv2 to lv3 processing done
# The number of folders in 1 (67) and 2 (67) are equal.
# All IMOS Lv3 data processing completed, named as PL3 Stacked data_mode_3 - density fit - single_tanh

# %%
# importlib.reload(Processing)
# stack_variables = ['TEMP']
# Processing.Construct_PL3_data('PL2 Stacked data','PL3 Stacked data_mode_3 - interp density', stack_variables,nmodes=3, z_method = 'z_nom')

# %% [markdown]
# # Example

# %%
import cmocean

# %% [markdown]
# ## LV 2 DATA

# %%
current_path = os.getcwd()
lv2_example_file = 'PL2 Stacked data\stacked_LV2_NWSROW-2204.nc' #change as you like
file_name = os.path.join(current_path,lv2_example_file)

# %%
stacked_lv2 = xr.open_dataset(file_name).copy(deep=True)
dt_sec = 60*5 #second
import pIMOS.utils.plot as pp
# importlib.reload(pp)
#define how long of the obs
time_length_day = 30 #day
start_point = 5000
end_point = int(start_point+time_length_day*86400/dt_sec)
pp.stacked_scalar(stacked_lv2,fh=10,kd_correct=False, tind=np.arange(start_point, end_point),variable='TEMP')

# %% [markdown]
# ## LV 3 DATA

# %%
lv3_example_file = 'PL3 Stacked data_mode_3 - density fit - single_tanh\stacked_LV3_NWSROW-2204.nc' #change as you like
file_name = os.path.join(current_path,lv3_example_file)

# %%
file_name1 = r'C:\Users\21924032\GitHub\Yutao_PhD_codes\Aim2 Mode decomposition\notebooks\V3.0\PL3 Stacked data_mode_3 - density fit - single_tanh\stacked_LV3_NWSROW-2204.nc'
stacked_lv3 = xr.open_dataset(file_name1).copy(deep=True)
stacked_lv3['rhofit'].plot(y='z_interp', x='time')

# %%
import matplotlib.pyplot as plt
import cmocean

fig, axes = plt.subplots(2, 2, figsize=(16, 10),)
axes = axes.flatten()
# --- Color map plots ---
stacked_lv3['TEMP'].plot(ax=axes[0], cmap='cmo.thermal')
axes[0].set_title('Temperature')
axes[0].set_ylabel('Depth (m)')
stacked_lv3['sea_water_potential_density'].plot(ax=axes[1], cmap='cmo.dense')
axes[1].set_title('Density')
axes[1].set_ylabel('Depth (m)')
# --- Hide unused subplot (optional) ---
axes[2].axis('off')

# --- Line plot for A_n modes ---
line_styles = ['-', '--', ':']
colors = ['tab:blue', 'tab:orange', 'tab:green']

# Assuming stacked_lv3['A_n'] has a 'mode' dimension
for n, (ls, color) in enumerate(zip(line_styles, colors)):
    stacked_lv3['A_n'].sel(modes=n).plot(ax=axes[3], linestyle=ls, color=color, label=f'Mode={n+1}')

axes[3].set_title('A_n by Mode')
axes[3].legend()
axes[3].set_ylabel('Displacement (m)')  # adjust if needed

for ax in axes:
    # ax.xaxis.set_major_locator(plt.MaxNLocator(6))  # show ~6 ticks
    ax.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y-%m-%d'))
    ax.set_xlabel('')
    ax.set_title('')
fig.autofmt_xdate()  # auto rotate date labels    
plt.tight_layout()
plt.show()
